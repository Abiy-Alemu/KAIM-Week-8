# %%
import pandas as pd

# Load the datasets
fraud_data = pd.read_csv(r'C:\Users\MMM\Documents\10 Academy File\KAIM-Week-8-9\data\Fraud_Data.csv')
df_f =fraud_data
df_f.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
df_f.describe
# Out:
# <bound method NDFrame.describe of         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
# ...

# %%
df_f.isnull().sum()
# Out:
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64

# %%
df_f.dropna()
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
df_f.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_f.drop_duplicates()
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
# Correct data types
df_f['signup_time'] = pd.to_datetime(df_f['signup_time'])
df_f['purchase_time'] = pd.to_datetime(df_f['purchase_time'])

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[ns]
#  2   purchase_time   151112 non-null  datetime64[ns]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(4)
# memory usage: 12.7+ MB

# %%
df_f.columns
# Out:
# Index(['user_id', 'signup_time', 'purchase_time', 'purchase_value',
#        'device_id', 'source', 'browser', 'sex', 'age', 'ip_address', 'class'],
#       dtype='object')

# %% [markdown]
# # Univariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Univariate analysis
plt.figure(figsize=(10, 6))
sns.histplot(df_f['purchase_value'], bins=30, kde=True)
plt.title('Distribution of Purchase Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the plot style
sns.set(style="whitegrid")

# Create a figure for the plot
plt.figure(figsize=(12, 6))

# Plot a histogram with a KDE overlay for the 'age' column
sns.histplot(df_f['age'], bins=30, kde=True, color='skyblue', edgecolor='black')

# Add titles and labels
plt.title('Univariate Analysis of Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Bivariate analysis

# %%
# Bivariate analysis
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_f, x='age', y='purchase_value', hue='class')
plt.title('Age vs Purchase Value by Fraud Class')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='age', y='purchase_value', data=df_f, hue='class', palette='coolwarm', alpha=0.7)
plt.title('Age vs Purchase Value by Fraud Class', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Purchase Value', fontsize=14)
plt.legend(title='Class', labels=['Non-Fraudulent', 'Fraudulent'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='class', y='age', data=df_f, palette='coolwarm')
plt.title('Age Distribution by Fraud Class', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.xticks([0, 1], ['Non-Fraudulent', 'Fraudulent'])
plt.show()
# Out:
# C:\Users\MMM\AppData\Local\Temp\ipykernel_7680\2119963940.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=df_f, palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='class', y='purchase_value', data=df_f, palette='coolwarm')
plt.title('Purchase_value Distribution by Fraud Class', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Purchase_value', fontsize=14)
plt.xticks([0, 1], ['Non-Fraudulent', 'Fraudulent'])
plt.show()
# Out:
# C:\Users\MMM\AppData\Local\Temp\ipykernel_7680\3850318908.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='purchase_value', data=df_f, palette='coolwarm')

# %%
# Calculate the IQR for purchase_value
Q1 = df_f['purchase_value'].quantile(0.25)
Q3 = df_f['purchase_value'].quantile(0.75)
IQR = Q3 - Q1

# Filter out outliers based on the IQR range
filtered_df = df_f[(df_f['purchase_value'] >= (Q1 - 1.5 * IQR)) & (df_f['purchase_value'] <= (Q3 + 1.5 * IQR))]

# Plotting Age vs. Purchase Value without outliers
plt.figure(figsize=(12, 6))
sns.scatterplot(x='age', y='purchase_value', data=filtered_df, hue='class', palette='coolwarm', alpha=0.7)
plt.title('Age vs Purchase Value by Fraud Class (Without Outliers)', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Purchase Value', fontsize=14)
plt.legend(title='Class', labels=['Non-Fraudulent', 'Fraudulent'])
plt.show()
# Out:
# c:\Users\MMM\Documents\10 Academy File\KAIM-Week-8-9\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Calculate the IQR for age
Q1_age = df_f['age'].quantile(0.25)
Q3_age = df_f['age'].quantile(0.75)
IQR_age = Q3_age - Q1_age

# Filter out outliers based on the IQR range for age
filtered_df_age = df_f[(df_f['age'] >= (Q1_age - 1.5 * IQR_age)) & (df_f['age'] <= (Q3_age + 1.5 * IQR_age))]

# Plotting Age Distribution by Fraud Class without outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x='class', y='age', data=filtered_df_age, palette='coolwarm')
plt.title('Age Distribution by Fraud Class (Without Outliers)', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.xticks([0, 1], ['Non-Fraudulent', 'Fraudulent'])
plt.show()
# Out:
# C:\Users\MMM\AppData\Local\Temp\ipykernel_7680\2906635892.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=filtered_df_age, palette='coolwarm')

# %%
import pandas as pd

# Assuming df_f is the DataFrame with 'age', 'purchase_value', and 'class' columns

# Define the upper and lower limits for purchase_value
lower_limit = df_f['purchase_value'].quantile(0.01)  # Lower 1% limit
upper_limit = df_f['purchase_value'].quantile(0.99)  # Upper 99% limit

# Filter the DataFrame to remove outliers
df_f_filtered = df_f[(df_f['purchase_value'] >= lower_limit) & (df_f['purchase_value'] <= upper_limit)]

# Plot again to see the cleaned data
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))
sns.scatterplot(data=df_f_filtered, x='age', y='purchase_value', hue='class', palette='coolwarm', s=50, alpha=0.7)
plt.title('Age vs Purchase Value by Fraud Class (After Removing Outliers)')
plt.show()

# %%
import pandas as pd

# Assuming df_f is your DataFrame
# Define a function to remove outliers based on IQR
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)  # 25th percentile
    Q3 = df[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

    # Determine lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter the DataFrame to remove outliers
    filtered_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return filtered_df

# Remove outliers for 'purchase_value'
df_filtered_purchase_value = remove_outliers_iqr(df_f, 'purchase_value')

# Remove outliers for 'age'
df_filtered = remove_outliers_iqr(df_filtered_purchase_value, 'age')

# Display the shape of the original and filtered DataFrames
print("Original DataFrame shape:", df_f.shape)
print("Filtered DataFrame shape:", df_filtered.shape)

# Optional: Check for remaining outliers in the filtered DataFrame
print("Remaining outliers in purchase_value:",
      df_filtered[~df_filtered['purchase_value'].between(df_filtered['purchase_value'].quantile(0.25) - 1.5 * (df_filtered['purchase_value'].quantile(0.75) - df_filtered['purchase_value'].quantile(0.25)),
                                                       df_filtered['purchase_value'].quantile(0.75) + 1.5 * (df_filtered['purchase_value'].quantile(0.75) - df_filtered['purchase_value'].quantile(0.25)))].shape[0])

print("Remaining outliers in age:",
      df_filtered[~df_filtered['age'].between(df_filtered['age'].quantile(0.25) - 1.5 * (df_filtered['age'].quantile(0.75) - df_filtered['age'].quantile(0.25)),
                                               df_filtered['age'].quantile(0.75) + 1.5 * (df_filtered['age'].quantile(0.75) - df_filtered['age'].quantile(0.25)))].shape[0])
# Out:
# Original DataFrame shape: (151112, 11)
# Filtered DataFrame shape: (149277, 11)
# Remaining outliers in purchase_value: 305
# Remaining outliers in age: 0

# %%
import pandas as pd

# Load the datasets
creditcard_data = pd.read_csv(r'C:\Users\MMM\Documents\10 Academy File\KAIM-Week-8-9\data\creditcard.csv')
df_c =creditcard_data
df_c.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_c.describe
# Out:
# <bound method NDFrame.describe of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df_c.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df_c.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df_c.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df_c.drop_duplicates()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df_c.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram for 'Amount'
plt.figure(figsize=(10, 5))
sns.histplot(df_c['Amount'], bins=50, kde=True)
plt.title('Distribution of Amount')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# Box plot to check for outliers in 'Amount'
plt.figure(figsize=(10, 5))
sns.boxplot(x=df_c['Amount'])
plt.title('Box Plot of Amount')
plt.xlabel('Amount')
plt.show()

# %% [markdown]
# # Histograms for V1 to V28

# %%
# Histograms for V1 to V28
for col in df_c.columns[1:28]:  # Assuming V1 to V28 are the second to the last columns
    plt.figure(figsize=(10, 5))
    sns.histplot(df_c[col], bins=50, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# #Analyzing Amount vs. Class

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='Class', y='Amount', data=df_c)
plt.title('Amount by Fraud Class')
plt.xlabel('Fraud Class')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# #Analyzing V1 to V28 by Class

# %%
for col in df_c.columns[1:28]:  # V1 to V28
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Class', y=col, data=df_c)
    plt.title(f'{col} by Fraud Class')
    plt.xlabel('Fraud Class')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# #Handling outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv(r'C:\Users\MMM\Documents\10 Academy File\KAIM-Week-8-9\data\creditcard.csv')

# Step 1: Calculate the IQR for the 'Amount' column
Q1 = df_c['Amount'].quantile(0.25)  # 25th percentile
Q3 = df_c['Amount'].quantile(0.75)  # 75th percentile
IQR = Q3 - Q1  # Interquartile range

# Step 2: Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Filter out outliers
filtered_df = df_c[(df_c['Amount'] >= lower_bound) & (df_c['Amount'] <= upper_bound)]

# Step 4: Visualize the results
plt.figure(figsize=(12, 6))
sns.boxplot(x=filtered_df['Amount'])
plt.title('Box Plot of Amount After Outlier Removal')
plt.xlabel('Amount')
plt.show()

# Optional: Check the shape of the original and filtered dataset
print("Original dataset shape:", df_c.shape)
print("Filtered dataset shape:", filtered_df.shape)
# Out:
# Original dataset shape: (284807, 31)
# Filtered dataset shape: (252903, 31)

# %%
import pandas as pd

# Load the datasets
IpAddress_to_Country= pd.read_csv(r'C:\Users\MMM\Documents\10 Academy File\KAIM-Week-8-9\data\IpAddress_to_Country.csv')
df_I =IpAddress_to_Country
df_I.head()
# Out:
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %%
df_I.describe
# Out:
# <bound method NDFrame.describe of         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]>

# %%
df_I.isnull().sum()
# Out:
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %%
df_I.dropna()
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
df_I.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_I.drop_duplicates()
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
df_I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138846 entries, 0 to 138845
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   lower_bound_ip_address  138846 non-null  float64
#  1   upper_bound_ip_address  138846 non-null  int64
#  2   country                 138846 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %%
df_I.columns
# Out:
# Index(['lower_bound_ip_address', 'upper_bound_ip_address', 'country'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# Step 1: Calculate the IQR for lower_bound_ip_address and upper_bound_ip_address
for column in ['lower_bound_ip_address', 'upper_bound_ip_address']:
    Q1 = df_I[column].quantile(0.25)  # 25th percentile
    Q3 = df_I[column].quantile(0.75)  # 75th percentile
    IQR = Q3 - Q1  # Interquartile range

    # Step 2: Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Step 3: Filter out outliers
    df_I = df_I[(df_I[column] >= lower_bound) & (df_I[column] <= upper_bound)]

# Step 4: (Optional) Visualize the results for each column
plt.figure(figsize=(12, 6))

# Box plot for lower_bound_ip_address
plt.subplot(1, 2, 1)
sns.boxplot(x=df_I['lower_bound_ip_address'])
plt.title('Box Plot of Lower Bound IP Address After Outlier Removal')
plt.xlabel('Lower Bound IP Address')

# Box plot for upper_bound_ip_address
plt.subplot(1, 2, 2)
sns.boxplot(x=df_I['upper_bound_ip_address'])
plt.title('Box Plot of Upper Bound IP Address After Outlier Removal')
plt.xlabel('Upper Bound IP Address')

plt.tight_layout()
plt.show()

# Check the shape of the filtered dataset
print("Filtered dataset shape:", df_I.shape)
# Out:
# Filtered dataset shape: (138846, 3)

# %%
df_I.columns
# Out:
# Index(['lower_bound_ip_address', 'upper_bound_ip_address', 'country'], dtype='object')

# %% [markdown]
# ## 4. Merge Datasets for Geolocation Analysis

# %%
import numpy as np

# Ensure 'ip_address_int' is of integer type, replacing non-integer values with NaN
df_f['ip_address_int'] = pd.to_numeric(df_f['ip_address_int'], errors='coerce').fillna(0).astype(np.int64)

# Convert 'lower_bound_ip_address' and 'upper_bound_ip_address' to integer type in df_I
df_I['lower_bound_ip_address'] = pd.to_numeric(df_I['lower_bound_ip_address'], errors='coerce').fillna(0).astype(np.int64)
df_I['upper_bound_ip_address'] = pd.to_numeric(df_I['upper_bound_ip_address'], errors='coerce').fillna(0).astype(np.int64)

# Now proceed with the merge
merged_data = pd.merge(df_f, df_I, 
                       left_on='ip_address_int', 
                       right_on='lower_bound_ip_address',
                       how='left')

# Drop unnecessary columns after merging
merged_data.drop(['ip_address_int', 'lower_bound_ip_address', 'upper_bound_ip_address'], axis=1, inplace=True)

merged_data.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class country
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0     NaN
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0     NaN
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1     NaN
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0     NaN
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0     NaN

# %%
merged_data.shape
# Out:
# (151112, 12)

# %% [markdown]
# ## 5. Feature Engineering
# #1.Transaction Frequency and Velocity Calculation

# %%
# Assume 'user_id' is used for frequency calculation
# Calculate daily transaction frequency for each user
merged_data['transaction_date'] = pd.to_datetime(merged_data['purchase_time']).dt.date
transaction_frequency = merged_data.groupby(['user_id', 'transaction_date']).size().reset_index(name='daily_transaction_count')

# Merge the frequency back into the original dataset
merged_data = pd.merge(merged_data, transaction_frequency, on=['user_id', 'transaction_date'], how='left')

# Calculate transaction velocity (transactions per hour)
merged_data['hour_of_day'] = pd.to_datetime(merged_data['purchase_time']).dt.hour
hourly_transaction_velocity = merged_data.groupby(['user_id', 'hour_of_day']).size().reset_index(name='hourly_transaction_count')

# Merge the velocity back into the original dataset
merged_data = pd.merge(merged_data, hourly_transaction_velocity, on=['user_id', 'hour_of_day'], how='left')

merged_data.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class country  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0     NaN
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0     NaN
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1     NaN
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0     NaN
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0     NaN
#
#   transaction_date  daily_transaction_count  hour_of_day  \
# 0       2015-04-18                        1            2
# ...

# %% [markdown]
# #2.Time-Based Features

# %%
# Extract time-based features
merged_data['hour_of_day'] = pd.to_datetime(merged_data['purchase_time']).dt.hour
merged_data['day_of_week'] = pd.to_datetime(merged_data['purchase_time']).dt.dayofweek

# Optional: Calculate additional time-based features
merged_data['month_of_year'] = pd.to_datetime(merged_data['purchase_time']).dt.month
merged_data['is_weekend'] = merged_data['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

merged_data.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class country  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0     NaN
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0     NaN
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1     NaN
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0     NaN
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0     NaN
#
#   transaction_date  daily_transaction_count  hour_of_day  \
# 0       2015-04-18                        1            2
# ...

# %% [markdown]
# ## 6. Normalization and Scaling

# %%
from sklearn.preprocessing import StandardScaler

# Scale numerical features (e.g., 'purchase_value', 'daily_transaction_count', 'hourly_transaction_count')
scaler = StandardScaler()
merged_data[['purchase_value', 'daily_transaction_count', 'hourly_transaction_count']] = scaler.fit_transform(
    merged_data[['purchase_value', 'daily_transaction_count', 'hourly_transaction_count']])

merged_data.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11       -0.160204
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54       -1.142592
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45       -1.197169
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50        0.385567
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53        0.112681
#
#        device_id source browser sex  age    ip_address  class country  \
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0     NaN
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0     NaN
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1     NaN
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0     NaN
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0     NaN
#
#   transaction_date  daily_transaction_count  hour_of_day  \
# 0       2015-04-18                      0.0            2
# ...

# %% [markdown]
# ## 7. Encode Categorical Features

# %%
# One-hot encoding for categorical features (e.g., 'source', 'browser', 'sex', 'country')
merged_data = pd.get_dummies(merged_data, columns=['source', 'browser', 'sex', 'country'], drop_first=True)

merged_data.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11       -0.160204
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54       -1.142592
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45       -1.197169
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50        0.385567
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53        0.112681
#
#        device_id  age    ip_address  class transaction_date  \
# 0  QVPSPJUOCKZAR   39  7.327584e+08      0       2015-04-18
# 1  EOGFQPIZPYXFZ   53  3.503114e+08      0       2015-06-08
# 2  YSSKYOSJHPPLJ   53  2.621474e+09      1       2015-01-01
# 3  ATGTXKYKUDUQN   41  3.840542e+09      0       2015-05-04
# 4  NAUITBZFJKHWW   45  4.155831e+08      0       2015-09-09
#
#    daily_transaction_count  ...  day_of_week  month_of_year  is_weekend  \
# 0                      0.0  ...            5              4           1
# ...
